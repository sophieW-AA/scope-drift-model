# %%
# --- Run ---
import datetime
print('is there anything going on')
run_timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
print('is there anything going on')
# Ensure the correct packagess are installed
# !{sys.executable} -m pip install db-dtypes
# Out:
# is there anything going on
# is there anything going on

# %%
# import sys
# !{sys.executable} -m pip install --upgrade google-auth pandas-gbq google-cloud-bigquery

# %%
import subprocess, sys, os

"""
This output is:
 1. pubs.txt - Paper list for CWTS tool
    Columns: int_id  paper identifier for cwts, core_pub (always 1 as not using core feature, but it has to be in)

 2. cit_links.txt - Citation network edges
    Columns: 
    int_id1 - citing paper, 
    int_id2 - cited paper, 
    weight - citation strength 0-2 higher= stronger
    Note: Each edge appears twice (A→B and B→A) for undirected format
        paper 5 cites Paper 12  →  row: 5, 12, 0.85
        Paper 12 cites Paper 5  →  row: 12, 5, 0.85  (same edge, reversed)

 3. pub_metadata.txt - Paper details lookup table
    Columns: int_id, pub_id, is_frontiers, journal, date, title
    - int_id: sequential CWTS ID (joins to classification.txt)
    - pub_id: airak PublicationId (joins to BigQuery tables)
 JOIN KEY: int_id links all files together, this is cwts identifier
"""
print("ere")
env = os.environ.copy()
print("ere")
env["START_YEAR"] = "2020"
env["END_YEAR"] = "2026"
env["NETWORK_MODE"] = "full"
env["run_timestamp"] = run_timestamp
print("ere")
result = subprocess.run(
    [sys.executable, "cwts_export.py"], capture_output=True, text=True, env=env
)
print("ere")
print(result.stdout)
print(result.stderr)
print("last")
# Out:
# ere
# ere
# ere
# ere
#
# 2026-06-17 12:07:42,960 [INFO] ============================================================
# 2026-06-17 12:07:42,960 [INFO] Configuration
# 2026-06-17 12:07:42,960 [INFO] ============================================================
# 2026-06-17 12:07:42,960 [INFO]   BQ_PROJECT              : ocean-tech-adv-analytics-p-usr
# 2026-06-17 12:07:42,960 [INFO]   AIRAK_DATASET           : ocean-breeze-tier-1.airak
# 2026-06-17 12:07:42,960 [INFO]   NETWORK_MODE            : global
# 2026-06-17 12:07:42,960 [INFO]   START_YEAR              : 2026
# 2026-06-17 12:07:42,960 [INFO]   END_YEAR                : 2026
# 2026-06-17 12:07:42,961 [INFO]   TOP_N_JOURNALS          : 5
# 2026-06-17 12:07:42,961 [INFO]   JOURNAL_IDS_OVERRIDE    : (none)
# 2026-06-17 12:07:42,961 [INFO]   ENABLE_EDGE_WEIGHTS     : True
# 2026-06-17 12:07:42,961 [INFO]   TEMPORAL_DECAY_TAU      : 5.0
# 2026-06-17 12:07:42,961 [INFO]   SELF_CITE_JOURNAL_WEIGHT: 0.5
# 2026-06-17 12:07:42,961 [INFO]   ENABLE_BC_EDGES         : True
# 2026-06-17 12:07:42,961 [INFO]   BC_MIN_SHARED_REFS      : 3
# 2026-06-17 12:07:42,961 [INFO]   MAX_EXTERNAL_PAPERS     : 50000
# 2026-06-17 12:07:42,961 [INFO]   OUTPUT_DIR              : cwts_output
# 2026-06-17 12:07:42,961 [INFO] ============================================================
# 2026-06-17 12:07:42,961 [INFO] ============================================================
# 2026-06-17 12:07:42,961 [INFO] CWTS Export — Edge Weight Builder
# 2026-06-17 12:07:42,961 [INFO]   Mode: GLOBAL  |  Years: 2026-2026
# 2026-06-17 12:07:42,961 [INFO]   Edge weights: ON
# 2026-06-17 12:07:42,961 [INFO] ============================================================
# 2026-06-17 12:07:42,961 [INFO] Fetching top 5 Frontiers journals by publication count...
# /opt/micromamba/envs/jupyterlab/lib/python3.12/site-packages/google/cloud/bigquery/table.py:2082: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# 2026-06-17 12:07:44,348 [INFO]   Journal IDs: [3315714752512, 2826088480769, 2379411881984, 2405181685761, 2972117368834]
# 2026-06-17 12:07:44,348 [INFO] Fetching Frontiers publication IDs...
# /opt/micromamba/envs/jupyterlab/lib/python3.12/site-packages/google/cloud/bigquery/table.py:2082: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# 2026-06-17 12:07:45,971 [INFO]   16,999 Frontiers publications
# 2026-06-17 12:07:45,971 [INFO] Building GLOBAL network for 2026-2026 (every publication, no journal filter)...
# /opt/micromamba/envs/jupyterlab/lib/python3.12/site-packages/google/cloud/bigquery/table.py:2082: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# 2026-06-17 12:08:00,917 [INFO]   530,777 edges, 549,424 nodes (1,751 Frontiers core)
# 2026-06-17 12:08:00,917 [WARNING] Global mode: disabling bibliographic-coupling edges (no journal scope; query would be unbounded).
# 2026-06-17 12:08:00,917 [INFO] Fetching metadata for 549,424 nodes...
# 2026-06-17 12:08:00,937 [INFO]   Metadata batch 1/28...
# /opt/micromamba/envs/jupyterlab/lib/python3.12/site-packages/google/cloud/bigquery/table.py:2082: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# 2026-06-17 12:08:04,777 [INFO]   Metadata batch 2/28...
# /opt/micromamba/envs/jupyterlab/lib/python3.12/site-packages/google/cloud/bigquery/table.py:2082: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# 2026-06-17 12:08:08,420 [INFO]   Metadata batch 3/28...
# /opt/micromamba/envs/jupyterlab/lib/python3.12/site-packages/google/cloud/bigquery/table.py:2082: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# 2026-06-17 12:08:12,332 [INFO]   Metadata batch 4/28...
# /opt/micromamba/envs/jupyterlab/lib/python3.12/site-packages/google/cloud/bigquery/table.py:2082: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# 2026-06-17 12:08:16,984 [INFO]   Metadata batch 5/28...
# /opt/micromamba/envs/jupyterlab/lib/python3.12/site-packages/google/cloud/bigquery/table.py:2082: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# 2026-06-17 12:08:20,662 [INFO]   Metadata batch 6/28...
# /opt/micromamba/envs/jupyterlab/lib/python3.12/site-packages/google/cloud/bigquery/table.py:2082: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# 2026-06-17 12:08:25,070 [INFO]   Metadata batch 7/28...
# /opt/micromamba/envs/jupyterlab/lib/python3.12/site-packages/google/cloud/bigquery/table.py:2082: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# 2026-06-17 12:08:28,914 [INFO]   Metadata batch 8/28...
# /opt/micromamba/envs/jupyterlab/lib/python3.12/site-packages/google/cloud/bigquery/table.py:2082: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# 2026-06-17 12:08:32,802 [INFO]   Metadata batch 9/28...
# /opt/micromamba/envs/jupyterlab/lib/python3.12/site-packages/google/cloud/bigquery/table.py:2082: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# 2026-06-17 12:08:36,891 [INFO]   Metadata batch 10/28...
# /opt/micromamba/envs/jupyterlab/lib/python3.12/site-packages/google/cloud/bigquery/table.py:2082: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# 2026-06-17 12:08:42,048 [INFO]   Metadata batch 11/28...
# /opt/micromamba/envs/jupyterlab/lib/python3.12/site-packages/google/cloud/bigquery/table.py:2082: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# 2026-06-17 12:08:45,682 [INFO]   Metadata batch 12/28...
# /opt/micromamba/envs/jupyterlab/lib/python3.12/site-packages/google/cloud/bigquery/table.py:2082: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# 2026-06-17 12:08:49,300 [INFO]   Metadata batch 13/28...
# /opt/micromamba/envs/jupyterlab/lib/python3.12/site-packages/google/cloud/bigquery/table.py:2082: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# 2026-06-17 12:08:52,987 [INFO]   Metadata batch 14/28...
# /opt/micromamba/envs/jupyterlab/lib/python3.12/site-packages/google/cloud/bigquery/table.py:2082: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# 2026-06-17 12:08:57,511 [INFO]   Metadata batch 15/28...
# /opt/micromamba/envs/jupyterlab/lib/python3.12/site-packages/google/cloud/bigquery/table.py:2082: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# 2026-06-17 12:09:01,202 [INFO]   Metadata batch 16/28...
# /opt/micromamba/envs/jupyterlab/lib/python3.12/site-packages/google/cloud/bigquery/table.py:2082: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# 2026-06-17 12:09:05,274 [INFO]   Metadata batch 17/28...
# /opt/micromamba/envs/jupyterlab/lib/python3.12/site-packages/google/cloud/bigquery/table.py:2082: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# 2026-06-17 12:09:09,055 [INFO]   Metadata batch 18/28...
# /opt/micromamba/envs/jupyterlab/lib/python3.12/site-packages/google/cloud/bigquery/table.py:2082: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# 2026-06-17 12:09:12,832 [INFO]   Metadata batch 19/28...
# /opt/micromamba/envs/jupyterlab/lib/python3.12/site-packages/google/cloud/bigquery/table.py:2082: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# 2026-06-17 12:09:16,716 [INFO]   Metadata batch 20/28...
# /opt/micromamba/envs/jupyterlab/lib/python3.12/site-packages/google/cloud/bigquery/table.py:2082: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# 2026-06-17 12:09:20,328 [INFO]   Metadata batch 21/28...
# /opt/micromamba/envs/jupyterlab/lib/python3.12/site-packages/google/cloud/bigquery/table.py:2082: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# 2026-06-17 12:09:24,745 [INFO]   Metadata batch 22/28...
# /opt/micromamba/envs/jupyterlab/lib/python3.12/site-packages/google/cloud/bigquery/table.py:2082: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# 2026-06-17 12:09:28,306 [INFO]   Metadata batch 23/28...
# /opt/micromamba/envs/jupyterlab/lib/python3.12/site-packages/google/cloud/bigquery/table.py:2082: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# 2026-06-17 12:09:32,155 [INFO]   Metadata batch 24/28...
# /opt/micromamba/envs/jupyterlab/lib/python3.12/site-packages/google/cloud/bigquery/table.py:2082: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# 2026-06-17 12:09:35,914 [INFO]   Metadata batch 25/28...
# /opt/micromamba/envs/jupyterlab/lib/python3.12/site-packages/google/cloud/bigquery/table.py:2082: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# 2026-06-17 12:09:39,413 [INFO]   Metadata batch 26/28...
# /opt/micromamba/envs/jupyterlab/lib/python3.12/site-packages/google/cloud/bigquery/table.py:2082: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# 2026-06-17 12:09:43,350 [INFO]   Metadata batch 27/28...
# /opt/micromamba/envs/jupyterlab/lib/python3.12/site-packages/google/cloud/bigquery/table.py:2082: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# 2026-06-17 12:09:47,819 [INFO]   Metadata batch 28/28...
# /opt/micromamba/envs/jupyterlab/lib/python3.12/site-packages/google/cloud/bigquery/table.py:2082: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# 2026-06-17 12:09:50,505 [INFO]   549,424 nodes (1,751 Frontiers core)
# 2026-06-17 12:09:50,513 [INFO] Applying edge weights (temporal decay + self-citation discount)...
# 2026-06-17 12:09:51,881 [INFO]   Decay mean=1.000  |  Self-citations: 37,374
# 2026-06-17 12:09:51,882 [INFO]   Combined weight mean=0.965
# 2026-06-17 12:09:51,905 [INFO] BC edges disabled (ENABLE_BC_EDGES=false)
# 2026-06-17 12:09:52,337 [INFO] Writing CWTS files to cwts_output/  (549,424 nodes)...
# 2026-06-17 12:10:00,583 [INFO]   pubs.txt        : 549,424 rows  (1,751 Frontiers)
#
#   0%|          | 0/1 [00:00<?, ?it/s]2026-06-17 12:10:07,109 [INFO]
# 549424 out of 549424 rows loaded.
#
# 100%|██████████| 1/1 [00:00<00:00, 6472.69it/s]
# 2026-06-17 12:10:07,109 [INFO]   → BigQuery: scope_drift_raw.pubs_raw_20260617_120742
# 2026-06-17 12:10:11,506 [INFO]   pub_metadata.txt: 549,424 rows
#
#   0%|          | 0/1 [00:00<?, ?it/s]2026-06-17 12:10:26,658 [INFO]
# 549424 out of 549424 rows loaded.
#
# 100%|██████████| 1/1 [00:00<00:00, 5940.94it/s]
# 2026-06-17 12:10:26,659 [INFO]   → BigQuery: scope_drift_raw.pub_metadata_raw_20260617_120742
# 2026-06-17 12:10:29,246 [INFO]   cit_links.txt   : 1,057,458 rows  (528,729 unique × 2 directions)
#
#   0%|          | 0/1 [00:00<?, ?it/s]2026-06-17 12:10:41,634 [INFO]
# 1057458 out of 1057458 rows loaded.
#
# 100%|██████████| 1/1 [00:00<00:00, 6898.53it/s]
# 2026-06-17 12:10:41,634 [INFO]   → BigQuery: scope_drift_raw.cit_links_raw_20260617_120742
#
# last

# %%
import subprocess
import datetime
import os
import pandas as pd
import pandas_gbq

# --- Parameters ---
params = {
    "largest_component_only": "true",
    "iterations": "100",
    "micro_resolution": "4e-4",
    "micro_min_cluster_size": "200",
    "meso_resolution": "1e-6",
    "meso_min_cluster_size": "1000",
    "macro_resolution": "5e-7",
    "macro_min_cluster_size": "50000",
}

input_files = {
    "pubs": "cwts_output/pubs.txt",
    "cit_links": "cwts_output/cit_links.txt",
    "output": "cwts_output/classification.txt",
    "jar": "publicationclassification.jar",
}


result = subprocess.run(
    [
        "java",
        "-Xmx350g",
        "-cp",
        input_files["jar"],
        "nl.cwts.publicationclassification.run.PublicationClassificationCreator",
        input_files["pubs"],
        input_files["cit_links"],
        input_files["output"],
        params["largest_component_only"],
        params["iterations"],
        params["micro_resolution"],
        params["micro_min_cluster_size"],
        params["meso_resolution"],
        params["meso_min_cluster_size"],
        params["macro_resolution"],
        params["macro_min_cluster_size"],
    ],
    capture_output=True,
    text=True,
)

# --- Log ---
os.makedirs("logs", exist_ok=True)
log_path = f"logs/cwts_run_{run_timestamp}.log"

with open(log_path, "w") as f:
    f.write(f"CWTS Publication Classification Run\n")
    f.write(f"{'='*50}\n")
    f.write(f"Timestamp : {run_timestamp}\n\n")

    f.write(f"Input Files\n{'-'*30}\n")
    for k, v in input_files.items():
        f.write(f"  {k:<20}: {v}\n")

    f.write(f"\nParameters\n{'-'*30}\n")
    for k, v in params.items():
        f.write(f"  {k:<26}: {v}\n")

    f.write(f"\nReturn Code: {result.returncode}\n")

    f.write(f"\nSTDOUT\n{'-'*30}\n")
    f.write(result.stdout or "(empty)\n")

    f.write(f"\nSTDERR\n{'-'*30}\n")
    f.write(result.stderr or "(empty)\n")

print(f"Log written to: {log_path}")
print(result.stdout)
if result.stderr:
    print(result.stderr)

# Load classification.txt
classification = pd.read_csv(
    "cwts_output/classification.txt",
    sep="\t",
    header=None,
    names=["int_id", "micro", "meso", "macro"],
)

# Upload to BigQuery
BQ_DEST_PROJECT = "ocean-tech-adv-analytics-c-tfs"
BQ_DEST_DATASET = "scope_drift_raw"


# classification.to_gbq(
#     f"{dataset}.classification_raw_{run_timestamp}",
#     project_id=project,
#     if_exists="replace",
# )

# Upload to BigQuery

pandas_gbq.to_gbq(
    classification,
    f"{BQ_DEST_DATASET}.classification_raw_{run_timestamp}",
    project_id=BQ_DEST_PROJECT,
    if_exists="replace",
)
print(f"  → BigQuery: {BQ_DEST_DATASET}.classification_raw_{run_timestamp}")

# %%
print(result.stderr)

# %%
import pandas as pd



df = pd.read_csv(
    "cwts_output/classification.txt",
    sep="\t",
    header=None,
    names=["pub_no", "micro", "meso", "macro"],
)



print(f"Total classified: {len(df):,}")


for level in ["micro", "meso", "macro"]:


    vc = df[level].value_counts()


    print(f"\n{level.upper()}: {len(vc):,} clusters")


    print(f"  Largest : {vc.iloc[0]:,} ({vc.iloc[0]/len(df)*100:.1f}%)")


    print(f"  Smallest: {vc.iloc[-1]:,}")


    print(f"  Median  : {vc.median():.0f}")
# Out:
# Total classified: 30,711,801
#
# MICRO: 51,342 clusters
#   Largest : 19,087 (0.1%)
#   Smallest: 200
#   Median  : 365
#
# MESO: 656 clusters
#   Largest : 1,620,017 (5.3%)
#   Smallest: 1,001
#   Median  : 3995
#
# MACRO: 12 clusters
#   Largest : 12,870,565 (41.9%)
#   Smallest: 26,964
#   Median  : 165146

# %% [markdown]
# ### Labelling with GPT

# %%
import label_clusters

# Run the script
label_clusters.main()

# %%
from pathlib import Path
import pandas as pd

OUTPUT_DIR = Path("cwts_output")
classif_path = OUTPUT_DIR / "classification.txt"
titles_path = OUTPUT_DIR / "pub_titles.txt"
classif = pd.read_csv(
    classif_path,
    sep="\t",
    header=None,
    names=["pub_no", "micro", "meso", "macro"],
)

print("Loading titles...")
titles = pd.read_csv(
    titles_path,
    sep="\t",
    header=None,
    names=["pub_no", "title"],
)

merged = classif.merge(titles, on="pub_no")
print(f"Merged: {len(merged):,} publications")

# merged.sample(5000).to_csv('full_merged.csv')

# %%
merged.sample(5000).to_csv("merged_sample.csv")

# %%
pd.set_option("display.max_colwidth", None)
merged[["macro", "title"]].sample(500)

# %% [markdown]
# ### looking at scope

# %%
import pandas as pd
from pathlib import Path

core = pd.read_csv(
    "cwts_output/frontiers_core.txt",
    sep="\t",
    header=None,
    names=["pub_no", "is_frontiers", "journal"],
)

print(core["journal"].unique())

# %%
import importlib
import journal_scope

# Override config variables
journal_scope.SCOPE_LEVEL = "macro"
journal_scope.SCOPE_THRESHOLD = 0.80
journal_scope.MIN_PAPERS = 50
journal_scope.USE_GPT = False
journal_scope.OUTPUT_DIR = Path("cwts_output")

journal_scope.TARGET_JOURNALS = [
    "Frontiers in Immunology",
    "Frontiers in Public Health",
    "Frontiers in Medicine",
    "Frontiers in Oncology",
    "Frontiers in Psychology",
]

# Run
journal_scope.main()

# %%
pd.set_option("display.max_colwidth", 50)
pd.read_csv("cwts_output/journal_scope.csv")
